# %%
#importing pandas
import pandas as pd
a = ["Jwalitha", 'Ramya',
'Durga','Jahnavi','Lahari','Sunny','Dhanush']
r = pd.Series(a, index = [67,43,44,89,34,45,29])
print(r)
# Out:
# 67    Jwalitha
# 43       Ramya
# 44       Durga
# 89     Jahnavi
# 34      Lahari
# 45       Sunny
# 29     Dhanush
# dtype: object

# %%
df = pd.read_csv("/diabetcsv.csv")
print(df)
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative
#
# [768 rows x 9 columns]

# %%
df=pd.read_csv("/grades_withnulls.csv")
print(df)
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   NaN     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
df = pd.read_excel("/diabetcsv.xlsx",sheet_name=0)
print(df)
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative
#
# [768 rows x 9 columns]

# %%
df=pd.read_excel("/grades_withnulls (1)(1).xlsx",sheet_name=1)
print(df)
# Out:
#      azmat     vijaya dbdzbnsrbrb
# 0   rahima    lakshmi      rbrbrw
# 1   sairam     akcsak     bdrbrtj
# 2  dhanush  aesjcbvjn     tuilmdt

# %%
df = pd.read_csv("/grades_withnulls.csv")
print(df.head())
print(df.tail())
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0     Joe        K   9.8  10.0   9.9    A+       1
# 1  Rajesh        M   8.9   9.1   9.3     A       1
# 2  Kissan        V   9.9   9.8  10.0     A       0
# 3    Mary        N   7.7   8.0   NaN     B       0
# 4    Jeen        K   9.8   9.1   9.9    A+       1
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
df = pd.read_csv("/grades_withnulls.csv")
print(df.describe)
# Out:
# <bound method NDFrame.describe of      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   NaN     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# ...

# %%
df = pd.read_csv("/grades_withnulls.csv")
print(df.describe().T)
df.info(show_counts=True, memory_usage=True, verbose=True)
# Out:
#         count      mean       std  min  25%  50%  75%   max
# SEM1     14.0  8.992857  0.929404  7.7  8.0  9.1  9.8   9.9
# SEM2     17.0  9.000000  0.647109  8.0  9.0  9.1  9.3  10.0
# SEM3     16.0  9.100000  1.057670  7.0  9.2  9.3  9.9  10.0
# Placed   17.0  0.588235  0.507300  0.0  0.0  1.0  1.0   1.0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Names     17 non-null     object
#  1   Initials  17 non-null     object
#  2   SEM1      14 non-null     float64
#  3   SEM2      17 non-null     float64
#  4   SEM3      16 non-null     float64
#  5   Grade     17 non-null     object
#  6   Placed    17 non-null     int64
# dtypes: float64(3), int64(1), object(3)
# memory usage: 1.1+ KB

# %%
df = pd.read_csv("/grades_withnulls.csv")
print(df.shape)
print(df.shape[1])
print(df.shape[0])
# Out:
# (17, 7)
# 7
# 17

# %%
df = pd.read_csv("/grades_withnulls.csv")
print(df.columns)
# Out:
# Index(['Names', 'Initials', 'SEM1', 'SEM2', 'SEM3', 'Grade', 'Placed'], dtype='object')

# %%
df=pd.read_csv("/grades_withnulls.csv")
df2=df.copy()
df2.loc[2:5,'SEM1']=None
df2.head(7)
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0     Joe        K   9.8  10.0   9.9    A+       1
# 1  Rajesh        M   8.9   9.1   9.3     A       1
# 2  Kissan        V   9.9   9.8  10.0     A       0
# 3    Mary        N   7.7   8.0   NaN     B       0
# 4    Jeen        K   9.8   9.1   9.9    A+       1
# 5     Raj        M   8.9   9.1   9.3     A       1
# 6  Hassan        V   9.9   9.0   9.2     A       1

# %%
df2.isnull().head(7)
# Out:
#    Names  Initials   SEM1   SEM2   SEM3  Grade  Placed
# 0  False     False  False  False  False  False   False
# 1  False     False  False  False  False  False   False
# 2  False     False  False  False  False  False   False
# 3  False     False  False  False   True  False   False
# 4  False     False  False  False  False  False   False
# 5  False     False  False  False  False  False   False
# 6  False     False  False  False  False  False   False

# %%
df2.isnull().tail(7)
# Out:
#     Names  Initials   SEM1   SEM2   SEM3  Grade  Placed
# 10  False     False   True  False  False  False   False
# 11  False     False  False  False  False  False   False
# 12  False     False  False  False  False  False   False
# 13  False     False  False  False  False  False   False
# 14  False     False  False  False  False  False   False
# 15  False     False  False  False  False  False   False
# 16  False     False  False  False  False  False   False

# %%
print(df2.isnull().sum())
# Out:
# Names       0
# Initials    0
# SEM1        3
# SEM2        0
# SEM3        1
# Grade       0
# Placed      0
# dtype: int64

# %%
print(df2[['SEM1','Names']])
# Out:
#     SEM1   Names
# 0    9.8     Joe
# 1    8.9  Rajesh
# 2    9.9  Kissan
# 3    7.7    Mary
# 4    9.8    Jeen
# 5    8.9     Raj
# 6    9.9  Hassan
# 7    7.7    Mari
# 8    NaN    Jess
# 9    NaN  Rajini
# 10   NaN   Kiran
# 11   7.7    Maya
# 12   9.8   Jolin
# 13   8.9  Rajesh
# 14   9.3    Riya
# 15   9.9    Sana
# 16   7.7    Mark

# %%
print(df[df.index==3])
# Out:
#   Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 3  Mary        N   7.7   8.0   NaN     B       0

# %%
print(df[df.index.isin(range(2,5))])
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 2  Kissan        V   9.9   9.8  10.0     A       0
# 3    Mary        N   7.7   8.0   NaN     B       0
# 4    Jeen        K   9.8   9.1   9.9    A+       1

# %%
print(df2.loc[4])
# Out:
# Names       Jeen
# Initials       K
# SEM1         9.8
# SEM2         9.1
# SEM3         9.9
# Grade         A+
# Placed         1
# Name: 4, dtype: object

# %%
print(df2.loc[2:20])
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   NaN     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
print(df2.loc[3]==None)
# Out:
# Names       False
# Initials    False
# SEM1        False
# SEM2        False
# SEM3        False
# Grade       False
# Placed      False
# Name: 3, dtype: bool

# %%
df2.loc[[3,12,15,16,5]]
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 3    Mary        N   7.7   8.0   NaN     B       0
# 12  Jolin        K   9.8   9.1   9.9    A+       1
# 15   Sana        V   9.9   9.3   9.2     A       0
# 16   Mark        N   7.7   8.0   7.0     B       0
# 5     Raj        M   8.9   9.1   9.3     A       1

# %%
df2.iloc[1:20, :5]
# Out:
#      Names Initials  SEM1  SEM2  SEM3
# 1   Rajesh        M   8.9   9.1   9.3
# 2   Kissan        V   9.9   9.8  10.0
# 3     Mary        N   7.7   8.0   NaN
# 4     Jeen        K   9.8   9.1   9.9
# 5      Raj        M   8.9   9.1   9.3
# 6   Hassan        V   9.9   9.0   9.2
# 7     Mari        N   7.7   8.0   7.1
# 8     Jess        K   NaN   9.1   9.9
# 9   Rajini        M   NaN   9.1   9.3
# 10   Kiran        V   NaN   9.3   9.2
# 11    Maya        N   7.7   8.0   7.1
# 12   Jolin        K   9.8   9.1   9.9
# 13  Rajesh        M   8.9   9.1   9.3
# 14    Riya        M   9.3   9.9  10.0
# 15    Sana        V   9.9   9.3   9.2
# 16    Mark        N   7.7   8.0   7.0

# %%
df2.loc[df["Names"]=="Mary"]
# Out:
#   Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 3  Mary        N   7.7   8.0   NaN     B       0

# %%
df2[df.Grade=="A"]
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0

# %%
df2[df.SEM2==9.3]
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 10  Kiran        V   NaN   9.3   9.2     A       0
# 15   Sana        V   9.9   9.3   9.2     A       0

# %%
df2.loc[df["SEM1"]>9.2,["Names"]]
# Out:
#      Names
# 0      Joe
# 2   Kissan
# 4     Jeen
# 6   Hassan
# 12   Jolin
# 14    Riya
# 15    Sana

# %%
df3=df2.copy()
df3=df3.dropna()
df3
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
df3.dropna(inplace=True,axis=0)
df3
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
df3.dropna(inplace=True,how="all")
df3
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
mv=df3["SEM1"].mean()
df3=df3.fillna(mv)
print(df3)
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
mv=df3["SEM1"].mean()
df3=df3.fillna(9.2)
print(df3)
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0
