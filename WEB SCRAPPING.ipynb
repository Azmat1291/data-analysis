# %%
pip install pyspark
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.0/317.0 MB 2.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pyspark: filename=pyspark-3.5.1-py2.py3-none-any.whl size=317488493 sha256=e25cab098b18a11d613d4f488f8214d57eaf76583a70355da5b8591dfbc9d59b
#   Stored in directory: /root/.cache/pip/wheels/80/1d/60/2c256ed38dddce2fdd93be545214a63e02fbd8d74fb0b7f3a6
# Successfully built pyspark
# ...

# %%
from bs4 import BeautifulSoup
import requests

# %%
url="https://www.mha.gov.in/en/divisionofmha/finance-division"

# %%
page=requests.get(url)

# %%
soup=BeautifulSoup(page.text,'html')
print(soup)
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en" prefix="content: http://purl.org/rss/1.0/modules/content/  dc: http://purl.org/dc/terms/  foaf: http://xmlns.com/foaf/0.1/  og: http://ogp.me/ns#  rdfs: http://www.w3.org/2000/01/rdf-schema#  schema: http://schema.org/  sioc: http://rdfs.org/sioc/ns#  sioct: http://rdfs.org/sioc/types#  skos: http://www.w3.org/2004/02/skos/core#  xsd: http://www.w3.org/2001/XMLSchema# ">
# <head>
# <meta charset="utf-8"/>
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-KZCKB7BR2L"></script>
# <script>window.dataLayer = window.dataLayer || [];function gtag(){dataLayer.push(arguments)};gtag("js", new Date());gtag("set", "developer_id.dMDhkMT", true);gtag("config", "G-KZCKB7BR2L", {"groups":"default","page_placeholder":"PLACEHOLDER_page_location"});</script>
# <meta content="Drupal 9 (https://www.drupal.org)" name="Generator"/>
# <meta content="width" name="MobileOptimized"/>
# <meta content="true" name="HandheldFriendly"/>
# ...

# %%
title=soup.find('title')
print(title)
# Out:
# <title>Ministry of Home Affairs | Government of India</title>

# %%
print(title.text)
# Out:
# Ministry of Home Affairs | Government of India

# %%
table = soup.find('table')
print(table)
# Out:
# <table class="cols-3">
# <thead>
# <tr>
# <th class="views-field views-field-counter" id="view-counter-table-column" scope="col">SR-No</th>
# <th class="views-field views-field-field-title" id="view-field-title-table-column" scope="col">Title</th>
# <th class="views-field views-field-id" id="view-id-table-column" scope="col">Download/Link</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td class="views-field views-field-counter" headers="view-counter-table-column">1          </td>
# <td class="views-field views-field-field-title" headers="view-field-title-table-column">Finance Division of Ministry of Home Affairs          </td>
# <td class="views-field views-field-id" headers="view-id-table-column"><span class="file file--mime-application-pdf file--application-pdf">
# <a class="ext" href="/sites/default/files/2022-08/FinanceDivision_18062019.pdf" target="_blank">Download (74.63 KB) </a>
# </span>
# </td>
# </tr>
# <tr>
# ...

# %%
Headings = table.find_all('th')
print(Headings)
# Out:
# [<th class="views-field views-field-counter" id="view-counter-table-column" scope="col">SR-No</th>, <th class="views-field views-field-field-title" id="view-field-title-table-column" scope="col">Title</th>, <th class="views-field views-field-id" id="view-id-table-column" scope="col">Download/Link</th>]

# %%
Header = [i.text for i in Headings]
print(Header)
# Out:
# ['SR-No', 'Title', 'Download/Link']

# %%
import pandas as pd
df = pd.DataFrame(columns = Header)
df
# Out:
# Empty DataFrame
# Columns: [SR-No, Title, Download/Link]
# Index: []
# No charts were generated by quickchart

# %%
rows = table.find_all('tr')
print(rows)
print(df.columns)
# Out:
# [<tr>
# <th class="views-field views-field-counter" id="view-counter-table-column" scope="col">SR-No</th>
# <th class="views-field views-field-field-title" id="view-field-title-table-column" scope="col">Title</th>
# <th class="views-field views-field-id" id="view-id-table-column" scope="col">Download/Link</th>
# </tr>, <tr>
# <td class="views-field views-field-counter" headers="view-counter-table-column">1          </td>
# <td class="views-field views-field-field-title" headers="view-field-title-table-column">Finance Division of Ministry of Home Affairs          </td>
# <td class="views-field views-field-id" headers="view-id-table-column"><span class="file file--mime-application-pdf file--application-pdf">
# <a class="ext" href="/sites/default/files/2022-08/FinanceDivision_18062019.pdf" target="_blank">Download (74.63 KB) </a>
# </span>
# </td>
# </tr>, <tr>
# <td class="views-field views-field-counter" headers="view-counter-table-column">2          </td>
# ...

# %%
ind=1
for i in rows[1:84]:
  row_data = i.find_all('td')
  every_row_data = [i.text for i in row_data]
  print(every_row_data)
  df.loc[ind] = every_row_data
  ind = ind+1
# Out:
# ['1          ', 'Finance Division of Ministry of Home Affairs          ', '\nDownload (74.63 KB) \n\n']
# ['2          ', 'Principal Chief Controller of Accounts Org          ', '\nClick Here ']
# ['3          ', 'Output Outcome Monitoring Framework (OOMF) – For schemes less than Rs.500 crores.          ', '\nClick Here ']
# ['4          ', 'Budget at a Glance          ', '\nDownload (78.9 KB) \n\n']
# ['5          ', 'Detailed Demands for Grants (Vol-I)- 2023-24          ', '\nDownload (11.99 MB) \n\n']
# ['6          ', 'Detailed Demands for Grants (Vol-II)- 2023-24          ', '\nDownload (15.87 MB) \n\n']
# ['7          ', 'Detailed Demands for Grants (Vol-I)- 2022-23          ', '\nDownload (3.68 MB) \n\n']
# ['8          ', 'Detailed Demands for Grants (Vol-II)- 2022-23          ', '\nDownload (11.57 MB) \n\n']
# ['9          ', 'Detailed Demands for Grants (Vol-I)- 2021-22          ', '\nDownload (2.82 MB) \n\n']
# ...

# %%
df
df.to_csv("ministry of home affairs.csv")
