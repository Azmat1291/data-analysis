# %%
pip install seaborn

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#load example dataset
tips=sns.load_dataset("tips")
print(tips)
sns.scatterplot(x="total_bill",y="tip",data=tips,label='azmat')
plt.title("scatter plot of Total bill vs tip")
plt.xlabel("Total bill ($)")
plt.ylabel("Tip ($)")
plt.show()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#load example dataset
iris=sns.load_dataset("iris")
print(iris)
sns.scatterplot(x="sepal_length",y="sepal_width",data=iris)
plt.title("corelation heatmap of iris dataset")
plt.xlabel("sepal_length ($)")
plt.ylabel("sepal_width ($)")
plt.show()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#load example dataset
tips=sns.load_dataset("tips")
print(tips)
sns.barplot(x="day",y="total_bill",data=tips)
plt.title("average total bill by day")
plt.xlabel("Day of the week")
plt.ylabel("Average total bill($)")
plt.show()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#load example dataset
tips=sns.load_dataset("tips")
print(tips)
sns.boxplot(x="day",y="total_bill",data=tips)
plt.title("average total bill by day")
plt.xlabel("Day of the week")
plt.ylabel("Average total bill($)")
plt.show()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips=sns.load_dataset("tips")
sns.violinplot(x="day",y="total_bill",data=tips)
plt.title("Distribution of totalbill by day")
plt.xlabel("Day of the week")
plt.ylabel("Total Bill($)")
plt.show()

# %%
import pandas as pd
import seaborn as sns
a=pd.read_csv("/content/grades_withnulls.csv")
b=sns.lineplot(x="Names",y="Grade",data=a)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#load example dataset
iris=sns.load_dataset("iris")
print(iris)
correlation_matrix= iris.corr()
sns.heatmap(correlation_matrix,annot=True,cmap="coolwarm")
plt.title("corelation heatmap of iris dataset")
plt.show()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#load example dataset
titanic=sns.load_dataset("titanic")
sns.countplot(x="class",data=titanic)
plt.title("passenger class distribution")
plt.xlabel("class")
plt.ylabel("count")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#Load example dataset
tips=sns.load_dataset("tips")
print(tips)
#create a scatter plot
sns.countplot(x="day",data=tips,label='tips')
plt.legend(loc='best')
plt.title("scatter plot of Day of the week vs. Total bill")
plt.xlabel("Day of the week($)")
plt.ylabel("Total bill($)")
plt.show()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips=sns.load_dataset("tips")
sns.lmplot(x="tip",y="total_bill",data=tips)
plt.title("scatter plot of Day of the week vs. Total bill")
plt.xlabel("Day of the week($)")
plt.ylabel("Total bill($)")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#Load example dataset
tips=sns.load_dataset("tips")
print(tips)
#create a scatter plot
sns.jointplot(x="day",y="total_bill",data=tips,label='tips')
plt.legend(loc='best')
plt.title("scatter plot of Day of the week vs. Total bill")
plt.xlabel("Day of the week($)")
plt.ylabel("Total bill($)")
plt.show()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#Load example dataset
titanic=sns.load_dataset("titanic")
print(tips)
#create a scatter plot
g=sns.FacetGrid(titanic,col="class")
g.map(sns.histplot,"age")
plt.subplots_adjust(top=0.8)
g.fig.suptitle("Age Distribution by Passenger Class")
plt.show()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
attention=sns.load_dataset("attention")
print(attention)
correlation_matrix=attention.corr()
sns.heatmap(correlation_matrix,annot=True, cmap="coolwarm")
plt.title("correlation Heatmap of attention Dataset")
plt.show()
# Out:
#     Unnamed: 0  subject attention  solutions  score
# 0            0        1   divided          1    2.0
# 1            1        2   divided          1    3.0
# 2            2        3   divided          1    3.0
# 3            3        4   divided          1    5.0
# 4            4        5   divided          1    4.0
# 5            5        6   divided          1    5.0
# 6            6        7   divided          1    5.0
# 7            7        8   divided          1    5.0
# 8            8        9   divided          1    2.0
# 9            9       10   divided          1    6.0
# 10          10       11   focused          1    6.0
# 11          11       12   focused          1    8.0
# 12          12       13   focused          1    6.0
# 13          13       14   focused          1    8.0
# 14          14       15   focused          1    8.0
# 15          15       16   focused          1    6.0
# 16          16       17   focused          1    7.0
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
dots=sns.load_dataset("dots")
print(dots)
correlation_matrix=dots.corr()
sns.heatmap(correlation_matrix,annot=True, cmap="coolwarm")
plt.title("correlation Heatmap of dots Dataset")
plt.show()
# Out:
#     align choice  time  coherence  firing_rate
# 0    dots     T1   -80        0.0    33.189967
# 1    dots     T1   -80        3.2    31.691726
# 2    dots     T1   -80        6.4    34.279840
# 3    dots     T1   -80       12.8    32.631874
# 4    dots     T1   -80       25.6    35.060487
# ..    ...    ...   ...        ...          ...
# 843  sacc     T2   300        3.2    33.281734
# 844  sacc     T2   300        6.4    27.583979
# 845  sacc     T2   300       12.8    28.511530
# 846  sacc     T2   300       25.6    27.009804
# 847  sacc     T2   300       51.2    30.959302
#
# [848 rows x 5 columns]
# <ipython-input-4-0e454af351b6>:5: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix=dots.corr()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
anscombe=sns.load_dataset("anscombe")
print(anscombe)
correlation_matrix=anscombe.corr()
sns.heatmap(correlation_matrix,annot=True, cmap="coolwarm")
plt.title("correlation Heatmap of anscombe Dataset")
plt.show()
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
brain_networks=sns.load_dataset("brain_networks")
print(brain_networks)
correlation_matrix=brain_networks.corr()
sns.heatmap(correlation_matrix,annot=True, cmap="coolwarm")
plt.title("correlation Heatmap of brain_networks Dataset")
plt.show()
# Out:
#     network                    1                  1.1                   2  \
# 0      node                    1                    1                   1
# 1      hemi                   lh                   rh                  lh
# 2       NaN                  NaN                  NaN                 NaN
# 3         0    56.05574417114258    92.03103637695312   3.391575574874878
# 4         1     55.5472526550293     43.6900749206543  -65.49598693847656
# ..      ...                  ...                  ...                 ...
# 918     915  -7.4295125007629395    -4.81321907043457  -3.670536518096924
# 919     916   -33.55413818359375   -38.60562133789063  -25.66480255126953
# 920     917   -78.53956604003906   -74.19718933105469  -54.04159545898438
# 921     918  -103.23582458496094    -98.7442855834961  -40.10954284667969
# 922     919   -36.28886795043945  -10.762069702148438  -30.35626220703125
#
#                      2.1                    3                  3.1  \
# ...
